# %%
import numpy as np 
import matplotlib.pyplot as plt
import openpathsampling as paths
import aimmd 
import torch
import sys
import aimmdTIS
import openpathsampling.engines.toy as toys
# Out:
# WARNING:asyncmd.slurm:Could not initialize SLURM cluster handling. If you are sure SLURM (sinfo/sacct/etc) is available try calling `asyncmd.config.set_slurm_settings()` with the appropriate arguments.
# /Users/rbreeba/code/aimmd/aimmd/base/storage.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:aimmd:dCGPy not found. SymReg will not be available.
# WARNING:aimmd:Tensorflow/Keras not available
# WARNING:pymbar.timeseries:Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
# WARNING:pymbar.mbar_solvers:
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************

# %%
settings = {"n_harmonics": 0,
            "rotation_degrees": 0,
            "scale": 2}
pes = aimmdTIS.potential_switch("wolfe-quapp", settings)
n_harmonics = pes.n_harmonics
# Out:
# 123
# pot dimensions without oscillators: 2
# harmonic oscillators omegas:
# array([0., 0.])

# %%
visualizer = aimmdTIS.ToyAimmdVisualizer(pes=pes)
visualizer.plot_potential_contour()

# %%
ResourceDirectoryPath = ""
aimmd_store = aimmd.Storage(ResourceDirectoryPath+"resources_toy_examples/aimmd_storage_WolfeQuapp.h5", "r")
# Out:
# ERROR:aimmd.base.storage:The directory containing the storage changed, but we have no write intent on file, so we can not update it. KerasRCModel saving might/will not work as expected if you did not copy the KerasRCmodel directory yourself.
# WARNING:aimmd.base.storage:Opening storage without write intent, asyncmd trajectory value caching will not be performed in h5py (but most likely as seperate npz files).

# %%
model = aimmd_store.rcmodels["most_recent"]
# Out:
# WARNING:aimmd.base.rcmodel:aimmd storage passed as density collector cache file is open in read-only mode. No appending will be possible.

# %%
# move model to current device:
use_gpu = False
if torch.cuda.is_available() and use_gpu:
    model = aimmdTIS.Tools.model_to(model, 'cuda')
elif torch.backends.mps.is_available() and use_gpu:
    model = aimmdTIS.Tools.model_to(model, 'mps')
else: 
    model = aimmdTIS.Tools.model_to(model, 'cpu')

# %%
visualizer.q_space_2d_projection(model)

# %%
integ = toys.LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=2.5)
options={
    'integ' : integ,
    'n_frames_max' : 5000,
    'n_steps_per_frame' : 1
}
toy_eng = toys.Engine(
    options=options,
    topology=pes.topology
)
toy_eng.initialized = True

template = pes.template(toy_eng)
toy_eng.current_snapshot = template
paths.PathMover.engine = toy_eng

# Collective variables to define the states
opA = paths.CoordinateFunctionCV(name="opA", f=pes.stable_interface_function, center=pes.state_A)
opB = paths.CoordinateFunctionCV(name="opB", f=pes.stable_interface_function, center=pes.state_B)

# State volumes in CV space
stateA = paths.CVDefinedVolume(opA, 0.0, pes.state_boundary).named('StateA')
stateB = paths.CVDefinedVolume(opB, 0.0, pes.state_boundary).named('StateB')
#

# %%
descriptor_transform = paths.FunctionCV('descriptor_transform', lambda s: s.coordinates[0], cv_wrap_numpy_array=True).with_diskcache()

# %%
# Fake an initial trajectory
init_AB = paths.Trajectory(pes.simple_initial_path(100,toy_eng))

# %%
TIS_Framework = aimmdTIS.AIMMD_TIS(toy_eng, model, stateA, stateB, descriptor_transform=descriptor_transform)

# %%
storage = paths.Storage("simple_store_AIMMD_TIS.nc", "w", template=template)
storage.save(toy_eng)
# Out:
# (store.engines[DynamicsEngine] : 1 object(s),
#  10,
#  33869351140875605511810457793990754326)

# %%
print(storage.engines)
# Out:
# store.engines[DynamicsEngine] : 1 object(s)

# %%
interface_value = -6
TIS_Framework.run_single_TIS(100, storage, init_AB, interface_value)
# Out:
# No missing ensembles.
# No extra ensembles.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 interface_value = -6
# ----> 2 TIS_Framework.run_single_TIS(100, storage, init_AB, interface_value)
#
# File ~/code/aimmd-tis/src/aimmdTIS/TIS_AIMMD_setup.py:182, in AIMMD_TIS.run_single_TIS(self, n_mc_steps, storage, initial_path, interface_value, scheme_move, scheme_selector, scheme_modifier, gaussian_parameter_width, gausssian_parameter_shift, direction, directory)
#     180 initial_conditions.sanity_check()
#     181 # storage.save(initial_conditions)
# --> 182 storage.save(network)
#     183 storage.save(move_scheme)
#     184 sampler = paths.PathSampling(storage=storage,
#     185                     move_scheme=move_scheme,
#     186                     sample_set=initial_conditions)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:637, in NetCDFPlus.save(self, obj, idx)
#     635     store = self.find_store(obj)
#     636     store_idx = self.stores.index[store.__uuid__]
# --> 637     return store, store_idx, store.save(obj, idx)
#     639 # Could not save this object.
#     640 raise RuntimeWarning("Objects of type '%s' cannot be stored!" %
#     641                      obj.__class__.__name__)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/named.py:352, in NamedObjectStore.save(self, obj, idx)
#     349 obj.fix_name()
#     351 try:
# --> 352     reference = super(NamedObjectStore, self).save(obj)
#     353 except:
#     354     # if saving did not work unlock the name if is was un-fixed before
#     355     obj._name_fixed = obj_fixed
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:466, in ObjectStore._save(self, obj, idx)
#     465 def _save(self, obj, idx):
# --> 466     self.vars['json'][idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:893, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     890     pass
#     892 elif var_type == 'jsonobj':
# --> 893     setter = lambda v: self.simplifier.to_json_object(v)
#     894     getter = lambda v: self.simplifier.from_json(v)
#     896 elif var_type == 'json':
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:593, in ObjectJSON.to_json_object(self, obj)
#     590 def to_json_object(self, obj):
#     591     if hasattr(obj, 'base_cls') \
#     592             and type(obj) is not type and type(obj) is not abc.ABCMeta:
# --> 593         simplified = self.simplify_object(obj)
#     594     else:
#     595         simplified = self.simplify(obj)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:128, in ObjectJSON.simplify_object(self, obj)
#     125 def simplify_object(self, obj):
#     126     return {
#     127         '_cls': obj.__class__.__name__,
# --> 128         '_dict': self.simplify(obj.to_dict(), obj.base_cls_name)
#     129     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:217, in ObjectJSON.simplify(self, obj, base_type)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
# --> 217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:218, in <dictcomp>(.0)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
# --> 218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:217, in ObjectJSON.simplify(self, obj, base_type)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
# --> 217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:218, in <dictcomp>(.0)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
# --> 218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:209, in ObjectJSON.simplify(self, obj, base_type)
#     202 simple = [
#     203     key for key in obj.keys()
#     204     if type(key) is str or type(key) is int]
#     206 if len(simple) < len(obj):
#     207     # other keys than int or str
#     208     result = {
# --> 209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:210, in <listcomp>(.0)
#     202 simple = [
#     203     key for key in obj.keys()
#     204     if type(key) is str or type(key) is int]
#     206 if len(simple) < len(obj):
#     207     # other keys than int or str
#     208     result = {
#     209         '_dict': [
# --> 210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:197, in ObjectJSON.simplify(self, obj, base_type)
#     195     return [self.simplify(o, base_type) for o in obj]
#     196 elif type(obj) is tuple:
# --> 197     return {'_tuple': [self.simplify(o, base_type) for o in obj]}
#     198 elif type(obj) is dict:
#     199     # we want to support storable objects as keys so we need to wrap
#     200     # dicts with care and store them using tuples
#     202     simple = [
#     203         key for key in obj.keys()
#     204         if type(key) is str or type(key) is int]
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:197, in <listcomp>(.0)
#     195     return [self.simplify(o, base_type) for o in obj]
#     196 elif type(obj) is tuple:
# --> 197     return {'_tuple': [self.simplify(o, base_type) for o in obj]}
#     198 elif type(obj) is dict:
#     199     # we want to support storable objects as keys so we need to wrap
#     200     # dicts with care and store them using tuples
#     202     simple = [
#     203         key for key in obj.keys()
#     204         if type(key) is str or type(key) is int]
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:686, in UUIDObjectJSON.simplify(self, obj, base_type)
#     680 store = self.storage._obj_store[obj.__class__]
#     681 if not store.nestable or obj.base_cls_name != base_type:
#     682     # this also returns the base class name used for storage
#     683     # store objects only if they are not creatable. If so
#     684     # they will only be created in their top instance and we
#     685     # use the simplify from the super class ObjectJSON
# --> 686     store.save(obj)
#     687     return {
#     688         '_hex_uuid': hex(obj.__uuid__),
#     689         '_store': store.prefix}
#     690     # return {
#     691     #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692     #     '_store': store.prefix}
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/named.py:352, in NamedObjectStore.save(self, obj, idx)
#     349 obj.fix_name()
#     351 try:
# --> 352     reference = super(NamedObjectStore, self).save(obj)
#     353 except:
#     354     # if saving did not work unlock the name if is was un-fixed before
#     355     obj._name_fixed = obj_fixed
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:466, in ObjectStore._save(self, obj, idx)
#     465 def _save(self, obj, idx):
# --> 466     self.vars['json'][idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:893, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     890     pass
#     892 elif var_type == 'jsonobj':
# --> 893     setter = lambda v: self.simplifier.to_json_object(v)
#     894     getter = lambda v: self.simplifier.from_json(v)
#     896 elif var_type == 'json':
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:593, in ObjectJSON.to_json_object(self, obj)
#     590 def to_json_object(self, obj):
#     591     if hasattr(obj, 'base_cls') \
#     592             and type(obj) is not type and type(obj) is not abc.ABCMeta:
# --> 593         simplified = self.simplify_object(obj)
#     594     else:
#     595         simplified = self.simplify(obj)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:128, in ObjectJSON.simplify_object(self, obj)
#     125 def simplify_object(self, obj):
#     126     return {
#     127         '_cls': obj.__class__.__name__,
# --> 128         '_dict': self.simplify(obj.to_dict(), obj.base_cls_name)
#     129     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:217, in ObjectJSON.simplify(self, obj, base_type)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
# --> 217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:218, in <dictcomp>(.0)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
# --> 218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:686, in UUIDObjectJSON.simplify(self, obj, base_type)
#     680 store = self.storage._obj_store[obj.__class__]
#     681 if not store.nestable or obj.base_cls_name != base_type:
#     682     # this also returns the base class name used for storage
#     683     # store objects only if they are not creatable. If so
#     684     # they will only be created in their top instance and we
#     685     # use the simplify from the super class ObjectJSON
# --> 686     store.save(obj)
#     687     return {
#     688         '_hex_uuid': hex(obj.__uuid__),
#     689         '_store': store.prefix}
#     690     # return {
#     691     #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692     #     '_store': store.prefix}
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/named.py:352, in NamedObjectStore.save(self, obj, idx)
#     349 obj.fix_name()
#     351 try:
# --> 352     reference = super(NamedObjectStore, self).save(obj)
#     353 except:
#     354     # if saving did not work unlock the name if is was un-fixed before
#     355     obj._name_fixed = obj_fixed
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:466, in ObjectStore._save(self, obj, idx)
#     465 def _save(self, obj, idx):
# --> 466     self.vars['json'][idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:893, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     890     pass
#     892 elif var_type == 'jsonobj':
# --> 893     setter = lambda v: self.simplifier.to_json_object(v)
#     894     getter = lambda v: self.simplifier.from_json(v)
#     896 elif var_type == 'json':
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:593, in ObjectJSON.to_json_object(self, obj)
#     590 def to_json_object(self, obj):
#     591     if hasattr(obj, 'base_cls') \
#     592             and type(obj) is not type and type(obj) is not abc.ABCMeta:
# --> 593         simplified = self.simplify_object(obj)
#     594     else:
#     595         simplified = self.simplify(obj)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:128, in ObjectJSON.simplify_object(self, obj)
#     125 def simplify_object(self, obj):
#     126     return {
#     127         '_cls': obj.__class__.__name__,
# --> 128         '_dict': self.simplify(obj.to_dict(), obj.base_cls_name)
#     129     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:217, in ObjectJSON.simplify(self, obj, base_type)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
# --> 217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:218, in <dictcomp>(.0)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
# --> 218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
#     [... skipping similar frames: UUIDObjectJSON.simplify at line 686 (2 times), <dictcomp> at line 218 (1 times), NetCDFPlus.create_type_delegate.<locals>.<lambda> at line 893 (1 times), NetCDFPlus.ValueDelegate.__setitem__ at line 114 (1 times), ObjectStore._save at line 466 (1 times), NamedObjectStore.save at line 352 (1 times), ObjectStore.save at line 894 (1 times), UUIDObjectJSON.simplify at line 694 (1 times), ObjectJSON.simplify at line 217 (1 times), ObjectJSON.simplify_object at line 128 (1 times), ObjectJSON.to_json_object at line 593 (1 times)]
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/named.py:352, in NamedObjectStore.save(self, obj, idx)
#     349 obj.fix_name()
#     351 try:
# --> 352     reference = super(NamedObjectStore, self).save(obj)
#     353 except:
#     354     # if saving did not work unlock the name if is was un-fixed before
#     355     obj._name_fixed = obj_fixed
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:466, in ObjectStore._save(self, obj, idx)
#     465 def _save(self, obj, idx):
# --> 466     self.vars['json'][idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:893, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     890     pass
#     892 elif var_type == 'jsonobj':
# --> 893     setter = lambda v: self.simplifier.to_json_object(v)
#     894     getter = lambda v: self.simplifier.from_json(v)
#     896 elif var_type == 'json':
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:593, in ObjectJSON.to_json_object(self, obj)
#     590 def to_json_object(self, obj):
#     591     if hasattr(obj, 'base_cls') \
#     592             and type(obj) is not type and type(obj) is not abc.ABCMeta:
# --> 593         simplified = self.simplify_object(obj)
#     594     else:
#     595         simplified = self.simplify(obj)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:128, in ObjectJSON.simplify_object(self, obj)
#     125 def simplify_object(self, obj):
#     126     return {
#     127         '_cls': obj.__class__.__name__,
# --> 128         '_dict': self.simplify(obj.to_dict(), obj.base_cls_name)
#     129     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:694, in UUIDObjectJSON.simplify(self, obj, base_type)
#     687             return {
#     688                 '_hex_uuid': hex(obj.__uuid__),
#     689                 '_store': store.prefix}
#     690             # return {
#     691             #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692             #     '_store': store.prefix}
# --> 694 return super(UUIDObjectJSON, self).simplify(obj, base_type)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:217, in ObjectJSON.simplify(self, obj, base_type)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
# --> 217     result = {
#     218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:218, in <dictcomp>(.0)
#     208     result = {
#     209         '_dict': [
#     210             self.simplify(tuple([key, o]))
#     211             for key, o in obj.items()
#     212             if key not in self.excluded_keys
#     213         ]}
#     214 else:
#     215     # simple enough, do it the old way
#     216     # FASTER VERSION NORMALLY
#     217     result = {
# --> 218         key: self.simplify(o) for key, o in obj.items()
#     219         if key not in self.excluded_keys
#     220     }
#     222     # SLOWER VERSION FOR DEBUGGING
#     223     # result = {}
#     224     # for key, o in obj.items():
#    (...)    229     # else:
#     230     # logger.debug("EXCLUDED")
#     232 return result
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:686, in UUIDObjectJSON.simplify(self, obj, base_type)
#     680 store = self.storage._obj_store[obj.__class__]
#     681 if not store.nestable or obj.base_cls_name != base_type:
#     682     # this also returns the base class name used for storage
#     683     # store objects only if they are not creatable. If so
#     684     # they will only be created in their top instance and we
#     685     # use the simplify from the super class ObjectJSON
# --> 686     store.save(obj)
#     687     return {
#     688         '_hex_uuid': hex(obj.__uuid__),
#     689         '_store': store.prefix}
#     690     # return {
#     691     #     '_obj_uuid': str(UUID(int=obj.__uuid__)),
#     692     #     '_store': store.prefix}
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/named.py:540, in UniqueNamedObjectStore.save(self, obj, idx)
#     537 self.reserve_name(name)
#     539 try:
# --> 540     reference = super(UniqueNamedObjectStore, self).save(obj, idx)
#     541 finally:
#     542     self.release_name(name)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/named.py:352, in NamedObjectStore.save(self, obj, idx)
#     349 obj.fix_name()
#     351 try:
# --> 352     reference = super(NamedObjectStore, self).save(obj)
#     353 except:
#     354     # if saving did not work unlock the name if is was un-fixed before
#     355     obj._name_fixed = obj_fixed
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/attribute.py:17, in PseudoAttributeStore._save(self, cv, idx)
#      16 def _save(self, cv, idx):
# ---> 17     self.vars['json'][idx] = cv
#      19     if cv.diskcache_enabled:
#      20         self.add_diskcache(cv)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:893, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     890     pass
#     892 elif var_type == 'jsonobj':
# --> 893     setter = lambda v: self.simplifier.to_json_object(v)
#     894     getter = lambda v: self.simplifier.from_json(v)
#     896 elif var_type == 'json':
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:593, in ObjectJSON.to_json_object(self, obj)
#     590 def to_json_object(self, obj):
#     591     if hasattr(obj, 'base_cls') \
#     592             and type(obj) is not type and type(obj) is not abc.ABCMeta:
# --> 593         simplified = self.simplify_object(obj)
#     594     else:
#     595         simplified = self.simplify(obj)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:128, in ObjectJSON.simplify_object(self, obj)
#     125 def simplify_object(self, obj):
#     126     return {
#     127         '_cls': obj.__class__.__name__,
# --> 128         '_dict': self.simplify(obj.to_dict(), obj.base_cls_name)
#     129     }
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/collectivevariable.py:389, in CoordinateFunctionCV.to_dict(self)
#     388 def to_dict(self):
# --> 389     dct = super(CoordinateFunctionCV, self).to_dict()
#     390     del dct['cv_time_reversible']
#     391     return dct
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/collectivevariable.py:241, in CallableCV.to_dict(self)
#     239 dct = super(CallableCV, self).to_dict()
#     240 callable_argument = self.__class__.args()[2]
# --> 241 dct[callable_argument] = ObjectJSON.callable_to_dict(self.cv_callable)
#     242 dct['cv_requires_lists'] = self.cv_requires_lists
#     243 dct['cv_wrap_numpy_array'] = self.cv_wrap_numpy_array
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/netcdfplus/dictify.py:384, in ObjectJSON.callable_to_dict(c)
#     382 if sys.version_info > (3, 11):
#     383     codec = make_callable_codec(safemode=False)
# --> 384     return codec.default(c)
#     386 # back to normal for older Python versions
#     387 # use marshal
#     388 global_vars = ObjectJSON._find_var(c, opcode.opmap['LOAD_GLOBAL'])
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/openpathsampling/experimental/simstore/callable_codec.py:131, in CallableCodec.default(self, obj)
#     128     if errors:
#     129         raise RuntimeError("Cannot store function! \n\n" + errors)
# --> 131     dillbytes = dill.dumps(obj, recurse=True)
#     132     return {
#     133         '__callable_name__': obj.__name__,
#     134         '_dilled': str(codecs.encode(dillbytes, 'base64'), 'utf-8')
#     135     }
#     136 return obj
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:289, in dumps(obj, protocol, byref, fmode, recurse, **kwds)
#     265 """
#     266 Pickle an object to a string.
#     267
#    (...)    286 Default values for keyword arguments can be set in :mod:`dill.settings`.
#     287 """
#     288 file = StringIO()
# --> 289 dump(obj, file, protocol, byref, fmode, recurse, **kwds)#, strictio)
#     290 return file.getvalue()
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:261, in dump(obj, file, protocol, byref, fmode, recurse, **kwds)
#     259 _kwds = kwds.copy()
#     260 _kwds.update(dict(byref=byref, fmode=fmode, recurse=recurse))
# --> 261 Pickler(file, protocol, **_kwds).dump(obj)
#     262 return
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:429, in Pickler.dump(self, obj)
#     427 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     428     logger.trace_setup(self)
# --> 429     StockPickler.dump(self, obj)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:1530, in save_instancemethod0(pickler, obj)
#    1527 @register(MethodType)
#    1528 def save_instancemethod0(pickler, obj):
#    1529     logger.trace(pickler, "Me1: %s", obj)
# -> 1530     pickler.save_reduce(MethodType, (obj.__func__, obj.__self__), obj=obj)
#    1531     logger.trace(pickler, "# Me1")
#    1532     return
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:1266, in save_module_dict(pickler, obj)
#    1263     if is_dill(pickler, child=False) and pickler._session:
#    1264         # we only care about session the first pass thru
#    1265         pickler._first_pass = False
# -> 1266     StockPickler.save_dict(pickler, obj)
#    1267     logger.trace(pickler, "# D2")
#    1268 return
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:1266, in save_module_dict(pickler, obj)
#    1263     if is_dill(pickler, child=False) and pickler._session:
#    1264         # we only care about session the first pass thru
#    1265         pickler._first_pass = False
# -> 1266     StockPickler.save_dict(pickler, obj)
#    1267     logger.trace(pickler, "# D2")
#    1268 return
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:1266, in save_module_dict(pickler, obj)
#    1263     if is_dill(pickler, child=False) and pickler._session:
#    1264         # we only care about session the first pass thru
#    1265         pickler._first_pass = False
# -> 1266     StockPickler.save_dict(pickler, obj)
#    1267     logger.trace(pickler, "# D2")
#    1268 return
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/dill/_dill.py:423, in Pickler.save(self, obj, save_persistent_id)
#     421     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     422     raise PicklingError(msg)
# --> 423 StockPickler.save(self, obj, save_persistent_id)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/pickle.py:578, in _Pickler.save(self, obj, save_persistent_id)
#     576 reduce = getattr(obj, "__reduce_ex__", None)
#     577 if reduce is not None:
# --> 578     rv = reduce(self.proto)
#     579 else:
#     580     reduce = getattr(obj, "__reduce__", None)
#
# File ~/miniconda3/envs/aimmd-tis/lib/python3.11/site-packages/h5py/_hl/base.py:368, in HLObject.__getnewargs__(self)
#     358 def __getnewargs__(self):
#     359     """Disable pickle.
#     360
#     361     Handles for HDF5 objects can't be reliably deserialised, because the
#    (...)    366     limitations, look at the h5pickle project on PyPI.
#     367     """
# --> 368     raise TypeError("h5py objects cannot be pickled")
#
# TypeError: h5py objects cannot be pickled

# %%
trajectories = [step.active[0].trajectory for step in storage.steps[::10]]
fig, ax = plt.subplots(1,1, figsize=(6,6))
visualizer.plot_potential_contour(ax=ax)
visualizer.plot_q_model_projection_contour(model, levels=[interface_value],ax=ax)
repcolordict = {0 : 'k-', 1 : 'r-', 2 : 'g-', 3 : 'b-', 4 : 'r-'}
for i, traj in enumerate(trajectories):
    ax.plot(traj.xyz[:,0,0], traj.xyz[:,0,1], repcolordict[i % 5])
visualizer.plot_states(ax=ax)
# Out:
# /Users/rbreeba/miniconda3/envs/py39_AIMMD-TIS/lib/python3.9/site-packages/aimmdTIS/Toy_analysis.py:158: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   ax.contour(x_2d,y_2d,states_plot_A, colors='red',linewidth=self.linewidth_theory)
# /Users/rbreeba/miniconda3/envs/py39_AIMMD-TIS/lib/python3.9/site-packages/aimmdTIS/Toy_analysis.py:159: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   ax.contour(x_2d,y_2d,states_plot_B, colors='blue', linewidth=self.linewidth_theory)

# %%
aimmd_store.close() 
storage.close()
